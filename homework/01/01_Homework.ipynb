# %% [markdown]
# Homework 1
# ----------------------
#
# In class, we looked at data and analysis around the death toll from Hurricane Maria. We ended the session looking at crime statistics from the FBI's Uniform Crime Reporting Program. Review that notebook before starting this assignment to refresh yourself on the syntax that R uses. The data we start with for this homework comes from the Major Cities Chiefs Association which has been surveying its members to get a sense of where crime is headed. Their report is here -- [MCCA Violent Crime Statistics](https://assets.documentcloud.org/documents/3023302/MCCA-Violent-Crime-Data-Midyear-2016-2015-8716.pdf).
#
# This little homework was part of a story by Tom Meagher and Gabe Dance at The Marshall Project. Have a look at thier [Crime in Context](https://www.themarshallproject.org/2016/08/18/crime-in-context) to see where these simple tools proved helpful. Read it over and take note of the kinds of statistics used in the story.
#
# The data we need is in a PDF table. PDF (the Portable Document Format) is really good for representing data to a printer -- creating a standard like this was a huge deal when PDF was introduced. Often, however, it becomes a vehicle for publishing data and then you start to see its weaknesses. Extracting data from a PDF will depend, first, on the kind of PDF it is. If you can "select" text from the document, you're in luck. There are several tools to help you get reasonably close to the data. If, on the other hand, your pages are essentially images, well, then you have to rely on "optical character recognition" programs that cluster black and white pixels, say, into letters and words and sentences.
#
# I used [Tabula](http://tabula.technology/) to pull the data from the Chiefs' report and convert it to something more usable, a CSV (comma separated values) file. CSV files are a popular format for tabular data. Each line in the file represents a different person or object or "entity." Measurements, or "attributes" on a given entity occupy one line in the file and are separated by commas. You can read more about the format [here](https://en.wikipedia.org/wiki/Comma-separated_values). [Download the data](https://www.dropbox.com/s/qjgc6xri89hg4ub/mcca.csv?dl=0) and have a look -- perhaps open it in your favorite spreadsheet program.
#
# To pull this data into R, we will again use the function `read.csv()`, but this time loading the data using a URL from github.com.

# %%
chiefs <- read.csv("https://github.com/cocteau/lede2018/raw/master/data/mcca.csv",as.is=TRUE)
head(chiefs)
# Out:
#   agency              hom16 hom15 rap16 rap15 rob16 rob15 agg16 agg15 non16
# 1 Albuquerque PD      34    25    156   199    753   861  1601  1608  125
# 2 Arlington PD        13     4    123   117    245   248   668   600   NA
# 3 Atlanta PD          57    45     72    72   1005  1003  1028  1064  161
# 4 Aurora PD           10     7    127   149    287   205   390   317   18
# 5 Austin PD           12     9    328   387    516   446  1114   942   NA
# 6 Baltimore County PD 16    14    141   134    583   652   823  1193   20
#   non15
# 1  NA
# 2  NA
# 3 161
# 4  15
# 5  NA
# 6  18

# %%
tail(chiefs)
# Out:
#    agency                   hom16 hom15 rap16 rap15 rob16 rob15 agg16 agg15
# 57 Tampa PD                 12    21     45    32    258   296   659   772
# 58 Tucson PD                11    16    221   213    537   516  1219   961
# 59 Tulsa PD                 30    27    185   170    459   426  1345  1176
# 60 Virginia Beach PD         8    12    102    75    131   126   136   129
# 61 Washington DC (Metro PD) 68    63    145   128   1491  1527  1102  1211
# 62 Wichita PD               10    13    183   165    289   329  1100   855
#    non16 non15
# 57 38    75
# 58 NA    NA
# 59 NA    NA
# 60 NA    NA
# 61 NA    NA
# 62 61    24

# %% [markdown]
# Again, "chiefs" is a data frame and `head()` and `tail()` give us a peak at the top and bottom. We can see how much there is using the command `dim()`.

# %%
dim(chiefs)
# Out:
# [1] 62 11

# %% [markdown]
# Which means 62 agencies, with 11 different attributes recorded for each.

# %% [markdown]
# Mid-year Crime Calculations
# ---------------------------
#
# That's enough background for one day. Let's look at the data. When the MCCA report appearaed over the summer, it generated some attention. [CNN](http://www.cnn.com/2016/07/25/politics/violent-crime-report-us-cities-homicides-rapes/), [Breitbart](http://www.breitbart.com/big-government/2016/07/26/survey-violent-crime-major-cities/), [The New York Times](http://www.nytimes.com/2016/05/14/us/murder-rates-cities-fbi.html) and a number of other outlets picked up the data and tried to draw some meaning from it. Have a read and see what you think.
#
# In the cell below, write a 3 sentence summary (or less) of what the data are, who collected them and why. With that completed, what kinds of questions do we want to ask about these data? Write down 5 questions.

# %% [markdown]
# **The data**
#
# The data is collected by [MCCA](https://www.majorcitieschiefs.com/), “a professional association of Chiefs and Sheriffs representing the largest cities in the United States and Canada”. MCCA’s purposes include:
#
# - To influence national public policy on law enforcement matters
# - To enhance the development of current and future leaders
# - To encourage and sponsor research
#
# The data set contains number of cases of five sorts of crime in 2015 and 2016.
#
# **My questions**
#
# - How does the number of each crime change from 2015 to 2016? (the big picture)
# - Which crime has the biggest aggregate number of cases?
# - Which city has the biggest decline in crime X?
# - Which city has the biggest surge in crime X?
# - What if we use number of crime / population instead of using the absolute values? Would the results change?

# %% [markdown]
# During his primary run, in a speech the RNC, Trump said that “Our president, who has used the pulpit of the presidency to divide us by race and color, has made America a more dangerous environment for everyone than frankly I have ever seen and anybody in this room has ever watched or seen.” This kicked off a wave of reporting about the safety of our cities. At the DNC in Philadelphia, Obama responded, “Donald Trump calls [America] ‘a divided crime scene’ that only he can fix. It doesn’t matter to him that illegal immigration and the crime rate are as low as they’ve been in decades…”
#
# How do we think about these conflicting impressions? We'll look at this question while learning a bit of R syntax (heck it's day 1).
#
# **Extracting data**. To try out your skills let's do a speed round of simple tasks. First, extract just the agency names from this table as a vector. Hint: You'll need to use the `$`. You can also use the `filter()` command and other verbs from `dplyr2`. Try them all out to get comfortable. The goal of this homework is to rehearse some of what we went over in class. I want you to be comfortable with both simple extractions like with the `$` and pandas-like subsetting, together with the verbs from `dplyr2`.

# %%
print(chiefs$agency)
# Out:
#  [1] "Albuquerque PD"                    "Arlington PD"
#  [3] "Atlanta PD"                        "Aurora PD"
#  [5] "Austin PD"                         "Baltimore County PD"
#  [7] "Baltimore PD"                      "Boston PD"
#  [9] "Charlotte-Mecklenburg PD"          "Chicago PD"
# [11] "Cincinnati PD"                     "Cleveland PD"
# [13] "Columbus Police"                   "Dallas PD"
# [15] "Denver PD"                         "El Paso PD"
# [17] "Fairfax County PD"                 "Fort Worth PD"
# [19] "Fresno PD"                         "Honolulu PD 2"
# [21] "Houston PD"                        "Indianapolis PD"
# [23] "Jacksonville Sheriff's Dept"       "Las Vegas Metropolitan PD"
# [25] "Long Beach PD"                     "Los Angeles County Sheriff's Dept"
# [27] "Los Angeles PD"                    "Louisville Metro PD"
# [29] "Memphis PD"                        "Mesa PD"
# [31] "Miami PD"                          "Miami-Dade PD"
# [33] "Milwaukee PD"                      "Montgomery Co PD"
# [35] "Nashville PD"                      "Nassau County PD 1"
# [37] "New Orleans PD"                    "New York City PD"
# [39] "Newark PD"                         "Oakland PD"
# [41] "Oklahoma City PD 2"                "Omaha NE PD"
# [43] "Orlando PD 3"                      "Philadelphia PD"
# [45] "Phoenix PD 4"                      "Pittsburgh PD"
# [47] "Prince George’s County PD"         "Raleigh PD"
# [49] "Sacramento PD"                     "Salt Lake City PD"
# [51] "San Antonio PD"                    "San Diego PD"
# [53] "San Francisco PD"                  "San Jose PD"
# [55] "Seattle PD"                        "St. Louis Metro PD"
# [57] "Tampa PD"                          "Tucson PD"
# [59] "Tulsa PD"                          "Virginia Beach PD"
# [61] "Washington DC (Metro PD)"          "Wichita PD"

# %% [markdown]
# Using `dplyr`:

# %%
library(dplyr)
library(dplyr, warn.conflicts = FALSE)
# Out:
# Warning message:
# “package ‘dplyr’ was built under R version 3.5.1”
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
select(chiefs, agency)
# Out:
#    agency
# 1  Albuquerque PD
# 2  Arlington PD
# 3  Atlanta PD
# 4  Aurora PD
# 5  Austin PD
# 6  Baltimore County PD
# 7  Baltimore PD
# 8  Boston PD
# 9  Charlotte-Mecklenburg PD
# 10 Chicago PD
# 11 Cincinnati PD
# 12 Cleveland PD
# 13 Columbus Police
# 14 Dallas PD
# 15 Denver PD
# 16 El Paso PD
# 17 Fairfax County PD
# 18 Fort Worth PD
# 19 Fresno PD
# 20 Honolulu PD 2
# 21 Houston PD
# 22 Indianapolis PD
# 23 Jacksonville Sheriff's Dept
# 24 Las Vegas Metropolitan PD
# 25 Long Beach PD
# 26 Los Angeles County Sheriff's Dept
# 27 Los Angeles PD
# 28 Louisville Metro PD
# 29 Memphis PD
# 30 Mesa PD
# ⋮  ⋮
# 33 Milwaukee PD
# 34 Montgomery Co PD
# 35 Nashville PD
# 36 Nassau County PD 1
# 37 New Orleans PD
# 38 New York City PD
# 39 Newark PD
# 40 Oakland PD
# 41 Oklahoma City PD 2
# 42 Omaha NE PD
# 43 Orlando PD 3
# 44 Philadelphia PD
# 45 Phoenix PD 4
# 46 Pittsburgh PD
# 47 Prince George’s County PD
# 48 Raleigh PD
# 49 Sacramento PD
# 50 Salt Lake City PD
# 51 San Antonio PD
# 52 San Diego PD
# 53 San Francisco PD
# 54 San Jose PD
# 55 Seattle PD
# 56 St. Louis Metro PD
# 57 Tampa PD
# 58 Tucson PD
# 59 Tulsa PD
# 60 Virginia Beach PD
# 61 Washington DC (Metro PD)
# 62 Wichita PD

# %% [markdown]
# ... and the vaues for homicides in 2016.

# %%
chiefs$hom16
# Out:
#  [1]  34  13  57  10  12  16 137  22  25 316  35  47  39  83  19   8   7  34  17
# [20]   8 158  61  59  90  15 110 134  54 106  11  27  37  54   8  34   3  67 161
# [39]  45  28  19  12  65 122  78  30  48   6  13   3  70  24  26  25  12  87  12
# [58]  11  30   8  68  10

# %% [markdown]
# **Computing crime rates**. We can compare the overall numbers of homicides in these 62 cities by adding or "sum"ming the columns for 2015 and 2016. Compute the total homicide count for 2015...

# %%
total_hom15 <- sum(chiefs$hom15,na.rm=TRUE)
total_hom15
# Out:
# [1] 2636

# %% [markdown]
# ... and then do it for for 2016.

# %%
total_hom16 <- sum(chiefs$hom16,na.rm=TRUE)
total_hom16
# Out:
# [1] 2980

# %% [markdown]
# To compare the overall change from 2015 to 2016, we might take the percentage change. That is the difference between homicides in 2016 and 2015 divided by the total in 2015. Use the two numbers above to compute this percent change...

# %%
(total_hom16 - total_hom15) / total_hom15
# Out:
# [1] 0.1305008

# %%
library(scales)

# %%
# cat() is concatenate, percent() is a verb from the library scales
cat('Homicides increased by', percent((total_hom16 - total_hom15) / total_hom15), 'from 2015 to 2016.')
# Out:
# Homicides increased by 13.1% from 2015 to 2016.

# %% [markdown]
# A big increase. Now, let's compute the rates of change for each agency. Rather than work on the crime categories separately, We will focuse on [violent crime](https://ucr.fbi.gov/crime-in-the-u.s/2011/crime-in-the-u.s.-2011/violent-crime/violent-crime). The FBI defines violent crime as the sum of homicides, rapes, robberies and aggravated assault. Let's use R to create these sums.
#
# We can add up the four crime categories as "vectors" -- meaning we can add up all four crime categories for each agency with a simple mathematical expression. Add up the data for 2016 for homicides, rapes, robberies and aggravated assaults.

# %%
chiefs$hom16 + chiefs$rap16 + chiefs$rob16 + chiefs$agg16
# Out:
#  [1]  2544  1049  2162   814  1970  1563  4991  2066  3161  8920  1086  2625
# [13]  2027  4774  2210  1354   338  2169  1563   744 11593  3402  2409  3255
# [25]  1408  7082 14078  2342  4335   923  1922  2899  4383   786  3701   510
# [37]  2001 18120  1231  2921  1676  1105  1193  7374    NA  1143   820   736
# [49]  1716   770  5111  2644  2988  1919  1885  2776   974  1988  2019   377
# [61]  2806  1582

# %% [markdown]
# ... And  store it back in the original data frame using the `$` notation or `mutate()` as we did in class. Call the new variable `vc16` for "violent crime 2016"

# %%
chiefs$vc16 <- chiefs$hom16 + chiefs$rap16 + chiefs$rob16 + chiefs$agg16

# %% [markdown]
# Have a look at the top of the file to make sure your column has been added.

# %%
head(chiefs)
# Out:
#   agency              hom16 hom15 rap16 rap15 rob16 rob15 agg16 agg15 non16
# 1 Albuquerque PD      34    25    156   199    753   861  1601  1608  125
# 2 Arlington PD        13     4    123   117    245   248   668   600   NA
# 3 Atlanta PD          57    45     72    72   1005  1003  1028  1064  161
# 4 Aurora PD           10     7    127   149    287   205   390   317   18
# 5 Austin PD           12     9    328   387    516   446  1114   942   NA
# 6 Baltimore County PD 16    14    141   134    583   652   823  1193   20
#   non15 vc16
# 1  NA   2544
# 2  NA   1049
# 3 161   2162
# 4  15    814
# 5  NA   1970
# 6  18   1563

# %% [markdown]
# Now, do the same thing, but add a column for 2015 calling it `vc15` and have a look again.

# %%
chiefs$vc15 <- chiefs$hom15 + chiefs$rap15 + chiefs$rob15 + chiefs$agg15

# %%
head(chiefs)
# Out:
#   agency              hom16 hom15 rap16 rap15 rob16 rob15 agg16 agg15 non16
# 1 Albuquerque PD      34    25    156   199    753   861  1601  1608  125
# 2 Arlington PD        13     4    123   117    245   248   668   600   NA
# 3 Atlanta PD          57    45     72    72   1005  1003  1028  1064  161
# 4 Aurora PD           10     7    127   149    287   205   390   317   18
# 5 Austin PD           12     9    328   387    516   446  1114   942   NA
# 6 Baltimore County PD 16    14    141   134    583   652   823  1193   20
#   non15 vc16 vc15
# 1  NA   2544 2693
# 2  NA   1049  969
# 3 161   2162 2184
# 4  15    814  678
# 5  NA   1970 1784
# 6  18   1563 1993

# %% [markdown]
# We can now look at the change for each city. This is defined as the difference between 2016 and 2016 as a fraction of 2015's total. As with simple addition of columns, we can express more complicated arithmetic expressions in one go. Write out your one line to compute the relative change.

# %%
(chiefs$vc16 - chiefs$vc15) / chiefs$vc15
# Out:
#  [1] -0.05532863  0.08255934 -0.01007326  0.20058997  0.10426009 -0.21575514
#  [7]  0.08241162 -0.04836481  0.21811175  0.23854485 -0.01985560 -0.07830056
# [13] -0.14000849  0.09949332  0.01376147  0.12833333  0.15358362  0.02070588
# [19]  0.18678815 -0.02490170  0.13656863  0.15049036 -0.01633320  0.19977884
# [25]  0.08141321  0.09138542  0.18471766  0.13414044  0.07755406 -0.09421001
# [31] -0.07239382 -0.08317521  0.00967519 -0.12276786  0.06106651  0.05590062
# [37]  0.21125908  0.01523980 -0.12880396 -0.07825813  0.09829620 -0.08450704
# [43] -0.06062992 -0.03582636          NA  0.08857143  0.07189542 -0.10462287
# [49] -0.06331878  0.19751166  0.27615481 -0.07065026 -0.13441483  0.12882353
# [55]  0.03231106 -0.01069138 -0.13113292  0.16529894  0.12229016  0.10233918
# [61] -0.04199385  0.16152717

# %% [markdown]
# And store the change in a column called `change` and have a brief look.

# %%
chiefs$change <- (chiefs$vc16 - chiefs$vc15) / chiefs$vc15

# %%
head(chiefs)
# Out:
#   agency              hom16 hom15 rap16 rap15 rob16 rob15 agg16 agg15 non16
# 1 Albuquerque PD      34    25    156   199    753   861  1601  1608  125
# 2 Arlington PD        13     4    123   117    245   248   668   600   NA
# 3 Atlanta PD          57    45     72    72   1005  1003  1028  1064  161
# 4 Aurora PD           10     7    127   149    287   205   390   317   18
# 5 Austin PD           12     9    328   387    516   446  1114   942   NA
# 6 Baltimore County PD 16    14    141   134    583   652   823  1193   20
#   non15 vc16 vc15 change
# 1  NA   2544 2693 -0.05532863
# 2  NA   1049  969  0.08255934
# 3 161   2162 2184 -0.01007326
# 4  15    814  678  0.20058997
# 5  NA   1970 1784  0.10426009
# 6  18   1563 1993 -0.21575514

# %% [markdown]
# Compute the so-called 6 number summary (or 5 number if you learned that plus a mean) of the per-city changes in violent crimes using the command `summary()`.

# %%
summary(chiefs$change)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.     NA's
# -0.21576 -0.06063  0.05590  0.04028  0.12882  0.27615        1

# %% [markdown]
# We might reasonably ask about which cities are on the rise and which have had falling crime numbers. We can use a "logical expression" for this. It will return a set of boolean data types, `TRUE` and `FALSE`. Compute the logical expression, returning `TRUE` and `FALSE` values whether crime is rising or falling between 2015 and 2016 in each city.

# %%
chiefs$change > 0
# Out:
#  [1] FALSE  TRUE FALSE  TRUE  TRUE FALSE  TRUE FALSE  TRUE  TRUE FALSE FALSE
# [13] FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE FALSE  TRUE
# [25]  TRUE  TRUE  TRUE  TRUE  TRUE FALSE FALSE FALSE  TRUE FALSE  TRUE  TRUE
# [37]  TRUE  TRUE FALSE FALSE  TRUE FALSE FALSE FALSE    NA  TRUE  TRUE FALSE
# [49] FALSE  TRUE  TRUE FALSE FALSE  TRUE  TRUE FALSE FALSE  TRUE  TRUE  TRUE
# [61] FALSE  TRUE

# %% [markdown]
# Notice we have an `NA` or missing value. One city is missing data. We can ask which crime statistics are `NA` by simply asking...

# %%
is.na(chiefs$change)
# Out:
#  [1] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [13] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [25] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [37] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE FALSE
# [49] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [61] FALSE FALSE

# %% [markdown]
# Use this vector of logical data (`TRUE` and `FALSE` values) to subset the `chiefs` data frame and keep just the row(s) that have a problem. Identify the problem.

# %%
chiefs[is.na(chiefs$change),]
# Out:
#    agency       hom16 hom15 rap16 rap15 rob16 rob15 agg16 agg15 non16 non15
# 45 Phoenix PD 4 78    52    NA    509   NA    1502  NA    2450  NA    NA
#    vc16 vc15 change
# 45 NA   4513 NA

# %% [markdown]
# Use the same logical vector and find out how many cities had missing data using the `sum()` command.

# %%
sum(is.na(chiefs$change))
# Out:
# [1] 1

# %%
# Additionally, this will return all rows with at least 1 NA:
# chiefs[rowSums(is.na(chiefs)) > 0,]

# %%
# And this will return a vector showing how many NA's there are for each column:
# colSums(is.na(chiefs))

# %% [markdown]
# Because there is an `NA`, we have to remove it if we want `sum()` to return a non-missing value. We know there are missing values and we've looked at where they came from. It's safe, then, to consider dropping them out when considering how many ups and downs we have.

# %%
sum(chiefs$change > 0, na.rm=TRUE)
# Out:
# [1] 36

# %% [markdown]
# And let's have a look. Use a histogram to show the data. What's a histogram again?

# %%
options(repr.plot.width=5, repr.plot.height=4)
hist(chiefs$change, breaks=1, main="Change in violent crimes from 2015 to 2016", xlab="percent change of violent crimes")
# Out:
# Plot with title “Change in violent crimes from 2015 to 2016”

# %%
options(repr.plot.width=5, repr.plot.height=4)
hist(chiefs$change, breaks=5, main="Change in violent crimes from 2015 to 2016", xlab="percent change of violent crimes")
# Out:
# Plot with title “Change in violent crimes from 2015 to 2016”

# %%
options(repr.plot.width=5, repr.plot.height=4)
hist(chiefs$change, breaks=10, main="Change in violent crimes from 2015 to 2016", xlab="percent change of violent crimes")
# Out:
# Plot with title “Change in violent crimes from 2015 to 2016”

# %% [markdown]
# What do you see? Change the `breaks` and tell me what you see.

# %% [markdown]
# - From 2015 to 2016, more cities saw an increase (rather than decrease) in violent crimes.
# - In both the two groups of cities (increase & decrease), the majority of the percent change values falls into the 5%~10% range, making two peaks visible in the histogram with `breaks=10` (or something larger).

# %% [markdown]
# Now, let's use that logical mask again, this time to find our errant row with missing data and to create a data frame that leaves it out. Call it `chiefs2`. One hint: Using `!` turns `TRUE` to `FALSE` and `FALSE` to `TRUE`. So the expression below identifies just those rows that are *not* `NA`'s.

# %%
!is.na(chiefs$change)
# Out:
#  [1]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [13]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [25]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [37]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE
# [49]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [61]  TRUE  TRUE

# %%
chiefs2 <- chiefs[!is.na(chiefs$change),]

# %%
# Making sure the new dataframe doesn't have a NA in the change column:
# sum(is.na(chiefs2$change))

# %% [markdown]
# Find those cities with a relative increase greater than 10%...

# %%
chiefs2[chiefs2$change>0.1,][c('agency','change')]
# Out:
#    agency                    change
# 4  Aurora PD                 0.2005900
# 5  Austin PD                 0.1042601
# 9  Charlotte-Mecklenburg PD  0.2181118
# 10 Chicago PD                0.2385448
# 16 El Paso PD                0.1283333
# 17 Fairfax County PD         0.1535836
# 19 Fresno PD                 0.1867882
# 21 Houston PD                0.1365686
# 22 Indianapolis PD           0.1504904
# 24 Las Vegas Metropolitan PD 0.1997788
# 27 Los Angeles PD            0.1847177
# 28 Louisville Metro PD       0.1341404
# 37 New Orleans PD            0.2112591
# 50 Salt Lake City PD         0.1975117
# 51 San Antonio PD            0.2761548
# 54 San Jose PD               0.1288235
# 58 Tucson PD                 0.1652989
# 59 Tulsa PD                  0.1222902
# 60 Virginia Beach PD         0.1023392
# 62 Wichita PD                0.1615272

# %% [markdown]
# ... and an increase less than 10%.

# %%
chiefs2[chiefs2$change>0 & chiefs2$change<0.1,][c('agency','change')]
# Out:
#    agency                            change
# 2  Arlington PD                      0.08255934
# 7  Baltimore PD                      0.08241162
# 14 Dallas PD                         0.09949332
# 15 Denver PD                         0.01376147
# 18 Fort Worth PD                     0.02070588
# 25 Long Beach PD                     0.08141321
# 26 Los Angeles County Sheriff's Dept 0.09138542
# 29 Memphis PD                        0.07755406
# 33 Milwaukee PD                      0.00967519
# 35 Nashville PD                      0.06106651
# 36 Nassau County PD 1                0.05590062
# 38 New York City PD                  0.01523980
# 41 Oklahoma City PD 2                0.09829620
# 46 Pittsburgh PD                     0.08857143
# 47 Prince George’s County PD         0.07189542
# 55 Seattle PD                        0.03231106

# %% [markdown]
# Now, use `chiefs2` to create a the percentage change for all the cities taken together. What do you see?

# %%
(sum(chiefs2$vc16) - sum(chiefs2$vc15)) / sum(chiefs2$vc15)
# Out:
# [1] 0.05439942

# %% [markdown]
# When all cities in the data set are taken as a whole, we see a 5.44% increase in violent crimes from 2015 to 2016.

# %% [markdown]
# National trends
# ---------------
#
# The data we've been looking captures just 2015-2016 -- well, six months of 2015 and six months of 2016. It is a bit dangerous to make interpretations based on just one year's data. Crime fluctuates naturally from year to year and those fluctuations are best understood in terms of larger overall trends. To assess these trends, we appeal to the Uniform Crime Reports compiled by the FBI. You can [access the raw data here.](https://www.icpsr.umich.edu/icpsrweb/NACJD/series/57) I have a nicer form of the data for you already [loaded on Github](https://github.com/cocteau/lede2018/raw/master/data/ucr_crime_1975_2015.csv).
#
# Let's bring it into R.

# %%
ucr <- read.csv("https://github.com/cocteau/lede2018/raw/master/data/ucr_crime_1975_2015.csv",as.is=TRUE)
head(ucr)
# Out:
#   ORI     year department_name   total_pop homs_sum rape_sum rob_sum
# 1 NM00101 1975 Albuquerque, N.M. 286238     30      181       819
# 2 TX22001 1975 Arlington, Texas  112478      5       28       113
# 3 GAAPD00 1975 Atlanta           490584    185      443      3887
# 4 CO00101 1975 Aurora, Colo.     116656      7       44       171
# 5 TX22701 1975 Austin, Texas     300400     33      190       529
# 6 MDBPD00 1975 Baltimore         864100    259      463      9055
#   agg_ass_sum violent_crime months_reported violent_per_100k homs_per_100k
# 1 1353         2383         12               832.5240        10.480789
# 2  132          278         12               247.1594         4.445314
# 3 3518         8033         12              1637.4362        37.710158
# 4  389          611         12               523.7622         6.000549
# 5  463         1215         12               404.4607        10.985353
# 6 6309        16086         12              1861.5901        29.973383
#   rape_per_100k rob_per_100k agg_ass_per_100k source url
# 1 63.23409       286.1255    472.6836         NA     NA
# 2 24.89376       100.4641    117.3563         NA     NA
# 3 90.30054       792.3210    717.1045         NA     NA
# 4 37.71773       146.5848    333.4591         NA     NA
# 5 63.24900       176.0985    154.1278         NA     NA
# 6 53.58176      1047.9111    730.1238         NA     NA

# %% [markdown]
# We've seen simple summaries and graphics for quantitative data. We have various tabular summaries for quantitative data. Here we `table()` the column of years for UCR reports to see how many cities are reporting per year.

# %%
table(ucr$year)
# Out:
# 1975 1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990
#   69   69   69   69   69   69   69   69   69   69   69   69   69   69   69   69
# 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006
#   69   69   69   69   69   69   69   69   69   69   69   69   69   69   69   69
# 2007 2008 2009 2010 2011 2012 2013 2014 2015
#   69   69   69   69   69   69   69   69   69

# %% [markdown]
# And here we are doing the same by department, to see how many years worth of data we have for each department. It's very regular!

# %%
table(ucr$department_name)
# Out:
#           Albuquerque, N.M.            Arlington, Texas
#                          41                          41
#                     Atlanta               Aurora, Colo.
#                          41                          41
#               Austin, Texas                   Baltimore
#                          41                          41
#       Baltimore County, Md.                      Boston
#                          41                          41
#               Buffalo, N.Y. Charlotte-Mecklenburg, N.C.
#                          41                          41
#                     Chicago                  Cincinnati
#                          41                          41
#                   Cleveland              Columbus, Ohio
#                          41                          41
#                      Dallas                      Denver
#                          41                          41
#                     Detroit              El Paso, Texas
#                          41                          41
#         Fairfax County, Va.           Fort Worth, Texas
#                          41                          41
#              Fresno, Calif.                    Honolulu
#                          41                          41
#                     Houston                Indianapolis
#                          41                          41
#          Jacksonville, Fla.            Kansas City, Mo.
#                          41                          41
#                   Las Vegas          Long Beach, Calif.
#                          41                          41
#                 Los Angeles  Los Angeles County, Calif.
#                          41                          41
#             Louisville, Ky.              Memphis, Tenn.
#                          41                          41
#                 Mesa, Ariz.                       Miami
#                          41                          41
#     Miami-Dade County, Fla.                   Milwaukee
#                          41                          41
#                 Minneapolis      Montgomery County, Md.
#                          41                          41
#            Nashville, Tenn.         Nassau County, N.Y.
#                          41                          41
#                    National                 New Orleans
#                          41                          41
#               New York City                Newark, N.J.
#                          41                          41
#             Oakland, Calif.               Oklahoma City
#                          41                          41
#                 Omaha, Neb.               Orlando, Fla.
#                          41                          41
#                Philadelphia                     Phoenix
#                          41                          41
#                  Pittsburgh              Portland, Ore.
#                          41                          41
# Prince George's County, Md.               Raleigh, N.C.
#                          41                          41
#          Sacramento, Calif.              Salt Lake City
#                          41                          41
#                 San Antonio                   San Diego
#                          41                          41
#               San Francisco                    San Jose
#                          41                          41
#                     Seattle              St. Louis, Mo.
#                          41                          41
#        Suffolk County, N.Y.                 Tampa, Fla.
#                          41                          41
#               Tucson, Ariz.                Tulsa, Okla.
#                          41                          41
#         Virginia Beach, Va.            Washington, D.C.
#                          41                          41
#               Wichita, Kan.
#                          41

# %%
summary(ucr$violent_crime)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#     154    3015    5136   29632    9058 1932274      35

# %% [markdown]
# The summary shows a few missing values of violent crime numbers. Pull out the cities missing data on `violent_crime`.

# %%
# "Pull out" interpretation 1: These are the cities missing data on violent_crime
ucr[is.na(ucr$violent_crime),][c('year','department_name','violent_crime')]
# Out:
#      year department_name       violent_crime
# 31   1975 Louisville, Ky.       NA
# 100  1976 Louisville, Ky.       NA
# 169  1977 Louisville, Ky.       NA
# 238  1978 Louisville, Ky.       NA
# 307  1979 Louisville, Ky.       NA
# 376  1980 Louisville, Ky.       NA
# 445  1981 Louisville, Ky.       NA
# 514  1982 Louisville, Ky.       NA
# 583  1983 Louisville, Ky.       NA
# 652  1984 Louisville, Ky.       NA
# 721  1985 Louisville, Ky.       NA
# 790  1986 Louisville, Ky.       NA
# 859  1987 Louisville, Ky.       NA
# 922  1988 Jacksonville, Fla.    NA
# 928  1988 Louisville, Ky.       NA
# 961  1988 Tampa, Fla.           NA
# 997  1989 Louisville, Ky.       NA
# 1066 1990 Louisville, Ky.       NA
# 1135 1991 Louisville, Ky.       NA
# 1204 1992 Louisville, Ky.       NA
# 1273 1993 Louisville, Ky.       NA
# 1342 1994 Louisville, Ky.       NA
# 1411 1995 Louisville, Ky.       NA
# 1480 1996 Louisville, Ky.       NA
# 1530 1997 Cincinnati            NA
# 1549 1997 Louisville, Ky.       NA
# 1599 1998 Cincinnati            NA
# 1618 1998 Louisville, Ky.       NA
# 1687 1999 Louisville, Ky.       NA
# 1756 2000 Louisville, Ky.       NA
# 1825 2001 Louisville, Ky.       NA
# 1894 2002 Louisville, Ky.       NA
# 2767 2015 Baltimore County, Md. NA
# 2773 2015 Cleveland             NA
# 2812 2015 Portland, Ore.        NA

# %%
# "Pull out" interpretation 2: drop those rows and save it back to the original dataframe
# ucr <- ucr[!is.na(ucr$violent_crime),]
# OR create a new dataframe
# ucr1 <- ucr[!is.na(ucr$violent_crime),]

# %% [markdown]
# Just to make sure we understand the columns, violent crime is meant to be a combination of homicides, rapes, robberies and aggravated assault. Let's form that sum and compare it to the violent crime column in the data set. Useful, but not necessary hint: The command `all()` takes a logical vector and asks "Are all the values `TRUE`?". If so, it returns `TRUE`.
#
# So, create a vector from the data set that represents the category of violent crimes, compare that total to the `violent_crime` column in the data set, testing if they are all equal to each other.

# %%
# These are the columns we want:
# ucr[c('homs_sum','rape_sum','rob_sum','agg_ass_sum')]

# %%
ucr$homs_sum + ucr$rape_sum + ucr$rob_sum + ucr$agg_ass_sum
# Out:
#    [1]   2383    278   8033    611   1215  16086   1259  11386   3350   1937
# [2581]   2705  18547   5458   3989  11417   1804   4856   6046   7932   3872
# [2591]   1795   7314   1654     NA   2958  52993   3220   7963   5474   2485
# [2601]   2508  17853   9458   2347   3093   3955   1780   3520   1302   6943
# [2611]   5529   5777   3547   3782   5661   1790   2162   3850   3949    751
# [2621]   7448   2896   4325   1837   5516   1429   3123   8725   4184   5037
# [2631]   3249   5093  25688   2858   5782   4446   8330   4093  14501   2522
# [2641]   1005   4440   2552   2276  20993  10479   5246   5876  11374   2346
# [2651]  16524   5323   3644  10890   1807   4945   6057   8194   4038   1687
# [2661]   6667   1394     NA   2965  52384   3516   7984   4998   2449   2316
# [2671]  17074   9492   2259   2941   3502   1683   3137   1487   8828   5303
# [2681]   7064   3215   3760   5077   1599   2097   3368   3827    738   7880
# [2691]   3069   4934   1854   5577   1430   3581   8346   4024   4749   3173
# [2701]   5054  24133   2719   5205   4640   8457   4002  13622   2671    969
# [2711]   4492   2382   2273  22008  10768   5853   5892  12876   2304  19171
# [2721]   5091   4015  11420   2119   4473   6571   8914   4093   1648   7289
# [2731]   1329     NA   3770  50564   3009   6910   4782   2458   2340  15925
# [2741]   8749   2455   2911   3161   1730   2968   1452   7704   5214   6761
# [2751]   3242   4005   5348   1576   2080   3443   3217    667   7810   2939
# [2761]   5406   1946   5203   1660   3497   9542     NA   4702   2887   5948
# [2771]  24663   2761     NA   4631   9038   4599  11846   2515    974   4359
# [2781]   2871   2437  21994  11124   5622   6709  14383   2766  25156   5173
# [2791]   4300  11449   1972   4473   6179   9583   4395   1964   7245   1318
# [2801]     NA   3736  50088   3072   6051   4828   2329   2525  16132   9261
# [2811]   2167     NA   3256   1676   3611   1642   8594   5582   6710   3400
# [2821]   4093   5762   1675   2298   3472   3628    626   8084   3839

# %%
all((ucr$homs_sum + ucr$rape_sum + ucr$rob_sum + ucr$agg_ass_sum) == ucr$violent_crime, na.rm=TRUE)
# Out:
# [1] TRUE

# %% [markdown]
# Just to be clear, let's look at places that have huge crime numbers...

# %%
ucr[ucr$violent_crime > 1000000,]
# Out:
#       ORI year department_name total_pop homs_sum rape_sum rob_sum agg_ass_sum
# NA    NA    NA NA              NA           NA    NA       NA      NA
# 41    NA  1975 National        NA        20510    NA       NA      NA
# NA.1  NA    NA NA              NA           NA    NA       NA      NA
# 110   NA  1976 National        NA        18780    NA       NA      NA
# NA.2  NA    NA NA              NA           NA    NA       NA      NA
# 179   NA  1977 National        NA        19120    NA       NA      NA
# NA.3  NA    NA NA              NA           NA    NA       NA      NA
# 248   NA  1978 National        NA        19560    NA       NA      NA
# NA.4  NA    NA NA              NA           NA    NA       NA      NA
# 317   NA  1979 National        NA        21460    NA       NA      NA
# NA.5  NA    NA NA              NA           NA    NA       NA      NA
# 386   NA  1980 National        NA        23040    NA       NA      NA
# NA.6  NA    NA NA              NA           NA    NA       NA      NA
# 455   NA  1981 National        NA        22520    NA       NA      NA
# NA.7  NA    NA NA              NA           NA    NA       NA      NA
# 524   NA  1982 National        NA        21010    NA       NA      NA
# NA.8  NA    NA NA              NA           NA    NA       NA      NA
# 593   NA  1983 National        NA        19308    NA       NA      NA
# NA.9  NA    NA NA              NA           NA    NA       NA      NA
# 662   NA  1984 National        NA        18692    NA       NA      NA
# NA.10 NA    NA NA              NA           NA    NA       NA      NA
# 731   NA  1985 National        NA        18976    NA       NA      NA
# NA.11 NA    NA NA              NA           NA    NA       NA      NA
# 800   NA  1986 National        NA        20613    NA       NA      NA
# NA.12 NA    NA NA              NA           NA    NA       NA      NA
# 869   NA  1987 National        NA        20096    NA       NA      NA
# NA.13 NA    NA NA              NA           NA    NA       NA      NA
# NA.14 NA    NA NA              NA           NA    NA       NA      NA
# 938   NA  1988 National        NA        20675    NA       NA      NA
# NA.15 NA    NA NA              NA           NA    NA       NA      NA
# ⋮     ⋮   ⋮    ⋮               ⋮         ⋮        ⋮        ⋮       ⋮
# NA.24 NA    NA NA              NA           NA    NA       NA      NA
# NA.25 NA    NA NA              NA           NA    NA       NA      NA
# 1559  NA  1997 National        NA        18208    NA       NA      NA
# NA.26 NA    NA NA              NA           NA    NA       NA      NA
# NA.27 NA    NA NA              NA           NA    NA       NA      NA
# 1628  NA  1998 National        NA        16974    NA       NA      NA
# NA.28 NA    NA NA              NA           NA    NA       NA      NA
# 1697  NA  1999 National        NA        15522    NA       NA      NA
# NA.29 NA    NA NA              NA           NA    NA       NA      NA
# 1766  NA  2000 National        NA        15586    NA       NA      NA
# NA.30 NA    NA NA              NA           NA    NA       NA      NA
# 1835  NA  2001 National        NA        16037    NA       NA      NA
# NA.31 NA    NA NA              NA           NA    NA       NA      NA
# 1904  NA  2002 National        NA        16229    NA       NA      NA
# 1973  NA  2003 National        NA        16528    NA       NA      NA
# 2042  NA  2004 National        NA        16148    NA       NA      NA
# 2111  NA  2005 National        NA        16740    NA       NA      NA
# 2180  NA  2006 National        NA        17309    NA       NA      NA
# 2249  NA  2007 National        NA        17128    NA       NA      NA
# 2318  NA  2008 National        NA        16465    NA       NA      NA
# 2387  NA  2009 National        NA        15399    NA       NA      NA
# 2456  NA  2010 National        NA        14722    NA       NA      NA
# 2525  NA  2011 National        NA        14661    NA       NA      NA
# 2594  NA  2012 National        NA        14827    NA       NA      NA
# 2663  NA  2013 National        NA        14319    NA       NA      NA
# 2732  NA  2014 National        NA        14164    NA       NA      NA
# NA.32 NA    NA NA              NA           NA    NA       NA      NA
# NA.33 NA    NA NA              NA           NA    NA       NA      NA
# 2801  NA  2015 National        NA        15696    NA       NA      NA
# NA.34 NA    NA NA              NA           NA    NA       NA      NA
#       violent_crime months_reported violent_per_100k homs_per_100k
# NA         NA       NA                 NA              NA
# 41    1039710       NA              487.8             9.6
# NA.1       NA       NA                 NA              NA
# 110   1004210       NA              467.8             8.7
# NA.2       NA       NA                 NA              NA
# 179   1029580       NA              475.9             8.8
# NA.3       NA       NA                 NA              NA
# 248   1085550       NA              497.8             9.0
# NA.4       NA       NA                 NA              NA
# 317   1208030       NA              548.9             9.8
# 869   NA            NA           NA               NA     NA
# NA.13 NA            NA           NA               NA     NA
# NA.14 NA            NA           NA               NA     NA
# 938   NA            NA           NA               NA     NA
# NA.15 NA            NA           NA               NA     NA
# ⋮     ⋮             ⋮            ⋮                ⋮      ⋮
# NA.24 NA            NA           NA               NA     NA
# NA.25 NA            NA           NA               NA     NA
# 1559  NA            NA           NA               NA     NA
# NA.26 NA            NA           NA               NA     NA
# NA.27 NA            NA           NA               NA     NA
# 1628  NA            NA           NA               NA     NA
# NA.28 NA            NA           NA               NA     NA
# 1697  NA            NA           NA               NA     NA
# NA.29 NA            NA           NA               NA     NA
# 1766  NA            NA           NA               NA     NA
# NA.30 NA            NA           NA               NA     NA
# 1835  NA            NA           NA               NA     NA
# NA.31 NA            NA           NA               NA     NA
# 1904  NA            NA           NA               NA     NA
# 1973  NA            NA           NA               NA     NA
# 2042  NA            NA           NA               NA     NA
# 2111  NA            NA           NA               NA     NA
# 2180  NA            NA           NA               NA     NA
# 2249  NA            NA           NA               NA     NA
# 2318  NA            NA           NA               NA     NA
# 2387  NA            NA           NA               NA     NA
# 2456  NA            NA           NA               NA     NA
# 2525  NA            NA           NA               NA     NA
# 2594  NA            NA           NA               NA     NA
# 2663  NA            NA           NA               NA     NA
# 2732  NA            NA           NA               NA     NA
# NA.32 NA            NA           NA               NA     NA
# NA.33 NA            NA           NA               NA     NA
# 2801  NA            NA           NA               NA     NA
# NA.34 NA            NA           NA               NA     NA

# %% [markdown]
# Or, using `dplyr2` verbs...

# %%
filter(ucr, violent_crime>1000000)
# Out:
#    ORI year department_name total_pop homs_sum rape_sum rob_sum agg_ass_sum
# 1  NA  1975 National        NA        20510    NA       NA      NA
# 2  NA  1976 National        NA        18780    NA       NA      NA
# 3  NA  1977 National        NA        19120    NA       NA      NA
# 4  NA  1978 National        NA        19560    NA       NA      NA
# 5  NA  1979 National        NA        21460    NA       NA      NA
# 6  NA  1980 National        NA        23040    NA       NA      NA
# 7  NA  1981 National        NA        22520    NA       NA      NA
# 8  NA  1982 National        NA        21010    NA       NA      NA
# 9  NA  1983 National        NA        19308    NA       NA      NA
# 10 NA  1984 National        NA        18692    NA       NA      NA
# 11 NA  1985 National        NA        18976    NA       NA      NA
# 12 NA  1986 National        NA        20613    NA       NA      NA
# 13 NA  1987 National        NA        20096    NA       NA      NA
# 14 NA  1988 National        NA        20675    NA       NA      NA
# 15 NA  1989 National        NA        21500    NA       NA      NA
# 16 NA  1990 National        NA        23438    NA       NA      NA
# 17 NA  1991 National        NA        24703    NA       NA      NA
# 18 NA  1992 National        NA        23760    NA       NA      NA
# 19 NA  1993 National        NA        24526    NA       NA      NA
# 20 NA  1994 National        NA        23326    NA       NA      NA
# 21 NA  1995 National        NA        21606    NA       NA      NA
# 22 NA  1996 National        NA        19645    NA       NA      NA
# 23 NA  1997 National        NA        18208    NA       NA      NA
# 24 NA  1998 National        NA        16974    NA       NA      NA
# 25 NA  1999 National        NA        15522    NA       NA      NA
# 26 NA  2000 National        NA        15586    NA       NA      NA
# 27 NA  2001 National        NA        16037    NA       NA      NA
# 28 NA  2002 National        NA        16229    NA       NA      NA
# 29 NA  2003 National        NA        16528    NA       NA      NA
# 30 NA  2004 National        NA        16148    NA       NA      NA
# 31 NA  2005 National        NA        16740    NA       NA      NA
# 32 NA  2006 National        NA        17309    NA       NA      NA
# 33 NA  2007 National        NA        17128    NA       NA      NA
# 34 NA  2008 National        NA        16465    NA       NA      NA
# 35 NA  2009 National        NA        15399    NA       NA      NA
# 36 NA  2010 National        NA        14722    NA       NA      NA
# 37 NA  2011 National        NA        14661    NA       NA      NA
# 38 NA  2012 National        NA        14827    NA       NA      NA
# 39 NA  2013 National        NA        14319    NA       NA      NA
# 40 NA  2014 National        NA        14164    NA       NA      NA
# 41 NA  2015 National        NA        15696    NA       NA      NA
#    violent_crime months_reported violent_per_100k homs_per_100k rape_per_100k
# 1  1039710       NA              487.8             9.6          NA
# 2  1004210       NA              467.8             8.7          NA
# 3  1029580       NA              475.9             8.8          NA
# 4  1085550       NA              497.8             9.0          NA
# 5  1208030       NA              548.9             9.8          NA
# 6  1344520       NA              596.6            10.2          NA
# 7  1361820       NA              593.5             9.8          NA
# 8  1322390       NA              570.8             9.1          NA
# 9  1258087       NA              538.1             8.3          NA
# 10 1273282       NA              539.9             7.9          NA
# 11 1327767       NA              558.1             8.0          NA
# 12 1489169       NA              620.1             8.6          NA
# 13 1483999       NA              612.5             8.3          NA
# 14 1566221       NA              640.6             8.5          NA
# 15 1646037       NA              666.9             8.7          NA
# 16 1820127       NA              729.6             9.4          NA
# 17 1911767       NA              758.2             9.8          NA
# 18 1932274       NA              757.7             9.3          NA
# 19 1926017       NA              747.1             9.5          NA
# 20 1857670       NA              713.6             9.0          NA
# 21 1798792       NA              684.5             8.2          NA
# 22 1688540       NA              636.6             7.4          NA
# 23 1636096       NA              611.0             6.8          NA
# 24 1533887       NA              567.6             6.3          NA
# 25 1426044       NA              523.0             5.7          NA
# 26 1425486       NA              506.5             5.5          NA
# 27 1439480       NA              504.5             5.6          NA
# 28 1423677       NA              494.4             5.6          NA
# 29 1383676       NA              475.8             5.7          NA
# 30 1360088       NA              463.2             5.5          NA
# 31 1390745       NA              469.0             5.6          NA
# 32 1435123       NA              479.3             5.8          NA
# 33 1422970       NA              471.8             5.7          NA
# 34 1394461       NA              458.6             5.4          NA
# 35 1325896       NA              431.9             5.0          NA
# 36 1251248       NA              404.5             4.8          NA
# 37 1206031       NA              387.1             4.7          NA
# 38 1214464       NA              386.9             4.7          NA
# 39 1168298       NA              369.1             4.5          NA
# 40 1153022       NA              361.6             4.4          NA
# 41 1197704       NA              372.6             4.9          NA
#    rob_per_100k agg_ass_per_100k source url
# 1  NA           NA               NA     NA
# 2  NA           NA               NA     NA
# 3  NA           NA               NA     NA
# 4  NA           NA               NA     NA
# 5  NA           NA               NA     NA
# 6  NA           NA               NA     NA
# 7  NA           NA               NA     NA
# 8  NA           NA               NA     NA
# 9  NA           NA               NA     NA
# 10 NA           NA               NA     NA
# 11 NA           NA               NA     NA
# 12 NA           NA               NA     NA
# 13 NA           NA               NA     NA
# 14 NA           NA               NA     NA
# 15 NA           NA               NA     NA
# 16 NA           NA               NA     NA
# 17 NA           NA               NA     NA
# 18 NA           NA               NA     NA
# 19 NA           NA               NA     NA
# 20 NA           NA               NA     NA
# 21 NA           NA               NA     NA
# 22 NA           NA               NA     NA
# 23 NA           NA               NA     NA
# 24 NA           NA               NA     NA
# 25 NA           NA               NA     NA
# 26 NA           NA               NA     NA
# 27 NA           NA               NA     NA
# 28 NA           NA               NA     NA
# 29 NA           NA               NA     NA
# 30 NA           NA               NA     NA
# 31 NA           NA               NA     NA
# 32 NA           NA               NA     NA
# 33 NA           NA               NA     NA
# 34 NA           NA               NA     NA
# 35 NA           NA               NA     NA
# 36 NA           NA               NA     NA
# 37 NA           NA               NA     NA
# 38 NA           NA               NA     NA
# 39 NA           NA               NA     NA
# 40 NA           NA               NA     NA
# 41 NA           NA               NA     NA

# %% [markdown]
# The extra `NA` rows correspond to the missing data entries in `violent_crime` that we found above. R will (bless its heart) just turn the entire row into missing values. That can be annoying in cases when we want `NA`'s to be removed from the table. In the next lecture we'll see some higher-level tools that will do this for us, but for now we can just add to our logical expression and take only those rows where the crime count is not missing and is bigger than 1000000. We join two logical conditions with an `&` for "and" and `|` for "or".

# %%
ucr[(!is.na(ucr$violent_crime)) & (ucr$violent_crime>1000000),]
# Out:
#      ORI year department_name total_pop homs_sum rape_sum rob_sum agg_ass_sum
# 41   NA  1975 National        NA        20510    NA       NA      NA
# 110  NA  1976 National        NA        18780    NA       NA      NA
# 179  NA  1977 National        NA        19120    NA       NA      NA
# 248  NA  1978 National        NA        19560    NA       NA      NA
# 317  NA  1979 National        NA        21460    NA       NA      NA
# 386  NA  1980 National        NA        23040    NA       NA      NA
# 455  NA  1981 National        NA        22520    NA       NA      NA
# 524  NA  1982 National        NA        21010    NA       NA      NA
# 593  NA  1983 National        NA        19308    NA       NA      NA
# 662  NA  1984 National        NA        18692    NA       NA      NA
# 731  NA  1985 National        NA        18976    NA       NA      NA
# 800  NA  1986 National        NA        20613    NA       NA      NA
# 869  NA  1987 National        NA        20096    NA       NA      NA
# 938  NA  1988 National        NA        20675    NA       NA      NA
# 1007 NA  1989 National        NA        21500    NA       NA      NA
# 1076 NA  1990 National        NA        23438    NA       NA      NA
# 1145 NA  1991 National        NA        24703    NA       NA      NA
# 1214 NA  1992 National        NA        23760    NA       NA      NA
# 1283 NA  1993 National        NA        24526    NA       NA      NA
# 1352 NA  1994 National        NA        23326    NA       NA      NA
# 1421 NA  1995 National        NA        21606    NA       NA      NA
# 1490 NA  1996 National        NA        19645    NA       NA      NA
# 1559 NA  1997 National        NA        18208    NA       NA      NA
# 1628 NA  1998 National        NA        16974    NA       NA      NA
# 1697 NA  1999 National        NA        15522    NA       NA      NA
# 1766 NA  2000 National        NA        15586    NA       NA      NA
# 1835 NA  2001 National        NA        16037    NA       NA      NA
# 1904 NA  2002 National        NA        16229    NA       NA      NA
# 1973 NA  2003 National        NA        16528    NA       NA      NA
# 2042 NA  2004 National        NA        16148    NA       NA      NA
# 2111 NA  2005 National        NA        16740    NA       NA      NA
# 2180 NA  2006 National        NA        17309    NA       NA      NA
# 2249 NA  2007 National        NA        17128    NA       NA      NA
# 2318 NA  2008 National        NA        16465    NA       NA      NA
# 2387 NA  2009 National        NA        15399    NA       NA      NA
# 2456 NA  2010 National        NA        14722    NA       NA      NA
# 2525 NA  2011 National        NA        14661    NA       NA      NA
# 2594 NA  2012 National        NA        14827    NA       NA      NA
# 2663 NA  2013 National        NA        14319    NA       NA      NA
# 2732 NA  2014 National        NA        14164    NA       NA      NA
# 2801 NA  2015 National        NA        15696    NA       NA      NA
#      violent_crime months_reported violent_per_100k homs_per_100k rape_per_100k
# 41   1039710       NA              487.8             9.6          NA
# 110  1004210       NA              467.8             8.7          NA
# 179  1029580       NA              475.9             8.8          NA
# 248  1085550       NA              497.8             9.0          NA
# 317  1208030       NA              548.9             9.8          NA
# 386  1344520       NA              596.6            10.2          NA
# 455  1361820       NA              593.5             9.8          NA
# 524  1322390       NA              570.8             9.1          NA
# 593  1258087       NA              538.1             8.3          NA
# 662  1273282       NA              539.9             7.9          NA
# 731  1327767       NA              558.1             8.0          NA
# 800  1489169       NA              620.1             8.6          NA
# 869  1483999       NA              612.5             8.3          NA
# 938  1566221       NA              640.6             8.5          NA
# 1007 1646037       NA              666.9             8.7          NA
# 1076 1820127       NA              729.6             9.4          NA
# 1145 1911767       NA              758.2             9.8          NA
# 1214 1932274       NA              757.7             9.3          NA
# 1283 1926017       NA              747.1             9.5          NA
# 1352 1857670       NA              713.6             9.0          NA
# 1421 1798792       NA              684.5             8.2          NA
# 1490 1688540       NA              636.6             7.4          NA
# 1559 1636096       NA              611.0             6.8          NA
# 1628 1533887       NA              567.6             6.3          NA
# 1697 1426044       NA              523.0             5.7          NA
# 1766 1425486       NA              506.5             5.5          NA
# 1835 1439480       NA              504.5             5.6          NA
# 1904 1423677       NA              494.4             5.6          NA
# 1973 1383676       NA              475.8             5.7          NA
# 2042 1360088       NA              463.2             5.5          NA
# 2111 1390745       NA              469.0             5.6          NA
# 2180 1435123       NA              479.3             5.8          NA
# 2249 1422970       NA              471.8             5.7          NA
# 2318 1394461       NA              458.6             5.4          NA
# 2387 1325896       NA              431.9             5.0          NA
# 2456 1251248       NA              404.5             4.8          NA
# 2525 1206031       NA              387.1             4.7          NA
# 2594 1214464       NA              386.9             4.7          NA
# 2663 1168298       NA              369.1             4.5          NA
# 2732 1153022       NA              361.6             4.4          NA
# 2801 1197704       NA              372.6             4.9          NA
#      rob_per_100k agg_ass_per_100k source url
# 41   NA           NA               NA     NA
# 110  NA           NA               NA     NA
# 179  NA           NA               NA     NA
# 248  NA           NA               NA     NA
# 317  NA           NA               NA     NA
# 386  NA           NA               NA     NA
# 455  NA           NA               NA     NA
# 524  NA           NA               NA     NA
# 593  NA           NA               NA     NA
# 662  NA           NA               NA     NA
# 731  NA           NA               NA     NA
# 800  NA           NA               NA     NA
# 869  NA           NA               NA     NA
# 938  NA           NA               NA     NA
# 1007 NA           NA               NA     NA
# 1076 NA           NA               NA     NA
# 1145 NA           NA               NA     NA
# 1214 NA           NA               NA     NA
# 1283 NA           NA               NA     NA
# 1352 NA           NA               NA     NA
# 1421 NA           NA               NA     NA
# 1490 NA           NA               NA     NA
# 1559 NA           NA               NA     NA
# 1628 NA           NA               NA     NA
# 1697 NA           NA               NA     NA
# 1766 NA           NA               NA     NA
# 1835 NA           NA               NA     NA
# 1904 NA           NA               NA     NA
# 1973 NA           NA               NA     NA
# 2042 NA           NA               NA     NA
# 2111 NA           NA               NA     NA
# 2180 NA           NA               NA     NA
# 2249 NA           NA               NA     NA
# 2318 NA           NA               NA     NA
# 2387 NA           NA               NA     NA
# 2456 NA           NA               NA     NA
# 2525 NA           NA               NA     NA
# 2594 NA           NA               NA     NA
# 2663 NA           NA               NA     NA
# 2732 NA           NA               NA     NA
# 2801 NA           NA               NA     NA

# %% [markdown]
# ... ah, there are national totals in this data set. So let's have a look at one municipality. Let's pull the data aside and make some plots!

# %%
miami <- filter(ucr, department_name=="Miami")
miami
# Out:
#    ORI     year department_name total_pop homs_sum rape_sum rob_sum agg_ass_sum
# 1  FL01306 1975 Miami           350742     98      178      2657    3280
# 2  FL01306 1976 Miami           338721     84      145      2313    2630
# 3  FL01306 1977 Miami           333713     84      178      2447    2637
# 4  FL01306 1978 Miami           330060     96      207      2832    3137
# 5  FL01306 1979 Miami           362840    134      261      3390    3040
# 6  FL01306 1980 Miami           335718    220      325      6890    4039
# 7  FL01306 1981 Miami           356734    210      382      6196    4423
# 8  FL01306 1982 Miami           365506    190      349      5123    4301
# 9  FL01306 1983 Miami           374769    144      365      4719    4556
# 10 FL01306 1984 Miami           400646    170      273      5705    4780
# 11 FL01306 1985 Miami           385892    131      284      5768    5003
# 12 FL01306 1986 Miami           396374    148      221      5767    5540
# 13 FL01306 1987 Miami           385089    128      202      5594    5385
# 14 FL01306 1988 Miami           389720    146      411      6398    6006
# 15 FL01306 1989 Miami           381206    132      285      7289    6387
# 16 FL01306 1990 Miami           358548    129      299      8172    7007
# 17 FL01306 1991 Miami           367945    125      236      8477    6582
# 18 FL01306 1992 Miami           373791    128      272      7065    6480
# 19 FL01306 1993 Miami           372519    127      204      7082    7089
# 20 FL01306 1994 Miami           379980    116      221      5841    6793
# 21 FL01306 1995 Miami           378720    110      198      5676    6943
# 22 FL01306 1996 Miami           384976    124      201      5139    6526
# 23 FL01306 1997 Miami           391766     98      189      4517    6214
# 24 FL01306 1998 Miami           372949     86      140      3797    5482
# 25 FL01306 1999 Miami           373450     63      113      3076    4609
# 26 FL01306 2000 Miami           362470     66      118      3077    4616
# 27 FL01306 2001 Miami           371863     66      118      2719    4307
# 28 FL01306 2002 Miami           379044     65       96      2706    4361
# 29 FL01306 2003 Miami           381651     74      107      2928    4048
# 9  1259.1757    1215.6822        NA
# 10 1423.9503    1193.0732        NA
# 11 1494.7187    1296.4767        NA
# 12 1454.9390    1397.6699        NA
# 13 1452.6512    1398.3780        NA
# 14 1641.6915    1541.1064        Miami Herald
# 15 1912.0895    1675.4721        NA
# 16 2279.1927    1954.2711        NA
# 17 2303.8769    1788.8543        NA
# 18 1890.0937    1733.5891        NA
# 19 1901.1111    1902.9902        NA
# 20 1537.1862    1787.7257        NA
# 21 1498.7326    1833.2805        NA
# 22 1334.8884    1695.1706        NA
# 23 1152.9842    1586.1509        NA
# 24 1018.1017    1469.9061        NA
# 25  823.6712    1234.1679        NA
# 26  848.8978    1273.4847        NA
# 27  731.1833    1158.2222        NA
# 28  713.9013    1150.5261        NA
# 29  767.1931    1060.6549        NA
# 30  614.5083    1018.4690        NA
# 31  519.9655    1029.8871        NA
# 32  537.2404     926.8732        NA
# 33  618.4004     840.2153        NA
# 34  564.5953     745.5464        NA
# 35  499.5169     659.5818        NA
# 36  464.6307     728.2386        NA
# 37  494.4419     662.6311        NA
# 38  505.8806     633.7989        NA
# 39  529.6443     612.3415        NA
# 40  424.1746     590.5269        NA
# 41  383.8171     602.0974        Crime in the U.S. 2015
#    url
# 1  NA
# 2  NA
# 3  NA
# 4  NA
# 5  NA
# 6  NA
# 7  NA
# 8  NA
# 9  NA
# 10 NA
# 11 NA
# 12 NA
# 13 NA
# 14 "MAJOR CRIMES UP MOST IN 4 YEARS," March 11, 1989, Miami Herald via Nexis
# 15 NA
# 16 NA
# 17 NA
# 18 NA
# 19 NA
# 20 NA
# 21 NA
# 22 NA
# 23 NA
# 24 NA
# 25 NA
# 26 NA
# 27 NA
# 28 NA
# 29 NA
# 30 NA
# 31 NA
# 32 NA
# 33 NA
# 34 NA
# 35 NA
# 36 NA
# 37 NA
# 38 NA
# 39 NA
# 40 NA
# 41 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls

# %%
plot(miami$year, miami$violent_per_100k)
# Out:
# plot without title

# %%
options(repr.plot.width=8,repr.plot.height=4)

plot(miami$year,miami$violent_per_100k,xlab="Year",ylab="Violent Crimes per 100K People",type="l",main="Crime Rate in Miami")
points(miami$year,miami$violent_per_100k,pch=19,cex=0.5)
# Out:
# Plot with title “Crime Rate in Miami”

# %% [markdown]
# Create a plot for a city larger than Miami and a plot for a city smaller than Miami.

# %% [markdown]
# - **Picking the cities**

# %%
# Miami's total population in 2015
miami_pop <- miami[miami$year==2015,]$total_pop
miami_pop
# Out:
# [1] 437969

# %%
# Pick out the cities that have a larger population than Miami in 2015
larger_cities <- ucr[(ucr$year==2015) & (ucr$total_pop > miami_pop) & (!is.na(ucr$ORI)),]
larger_cities
# Out:
#      ORI     year department_name             total_pop homs_sum rape_sum
# 2761 NM00101 2015 Albuquerque, N.M.            559721    43       404
# 2763 GAAPD00 2015 Atlanta                      464710    94       170
# 2765 TX22701 2015 Austin, Texas                938728    23       487
# 2766 MDBPD00 2015 Baltimore                    621252   344       287
# 2767 MD00301 2015 Baltimore County, Md.        828871    NA        NA
# 2768 MA01301 2015 Boston                       665258    38       240
# 2770 NC06001 2015 Charlotte-Mecklenburg, N.C.  877817    61       216
# 2771 ILCPD00 2015 Chicago                     2728695   478      1432
# 2774 OHCOP00 2015 Columbus, Ohio               847745    77       806
# 2789  7.116313     55.744455     225.90510     346.04966
# 2790  8.813433     27.339629     108.99879     320.07151
# 2791 11.902138     30.122695     227.02226     362.79480
# 2792 20.518713     80.554948     475.88215    1163.18305
# 2793  3.396782     51.164035      86.61795     277.47466
# 2795  7.195256     31.709325     138.96884     339.09735
# 2796 24.150566     72.618254     624.41706     874.91672
# 2798  2.873632     26.655410      60.04899     105.03619
# 2799 10.941767     77.048276     280.68672     732.33854
# 2800  1.225057      6.407991      52.30052      64.26838
# 2803  4.116545     26.242971     198.17887     357.22718
# 2806 11.575891     76.115448     189.02003     488.88318
# 2807 10.613552     38.474125     144.83076     321.05994
# 2809 17.859307     84.321442     431.49361     495.27685
# 2810  7.180666     65.138895     193.62152     327.81020
# 2812        NA            NA            NA            NA
# 2813  9.632351     36.194287     198.33886     231.03047
# 2814  3.878065     24.637116     154.66634     199.15002
# 2815  8.780581     21.440955     239.73029     467.41281
# 2817  6.422581     71.673274     135.69411     373.39794
# 2818  2.641976     40.415090      98.39575     257.12851
# 2819  6.135807     39.824863     417.92952     312.92618
# 2820  2.908504     36.356303     110.52316     179.84251
# 2821  3.364049     21.061869     224.07489     350.15358
# 2823  1.789105      5.889137      50.46766      66.71870
# 2825  5.852645     79.671497     199.93392     370.03823
# 2827  4.196141     22.747501      59.62937      51.67879
# 2828 24.098966     73.486972     506.37581     598.60643
#      source
# 2761 Crime in the U.S. 2015
# 2763 Crime in the U.S. 2015
# 2765 Crime in the U.S. 2015
# 2766 Crime in the U.S. 2015
# 2767
# 2768 Crime in the U.S. 2015
# 2770 Crime in the U.S. 2015
# 2771 Crime in the U.S. 2015
# 2774 Crime in the U.S. 2015
# 2775 Crime in the U.S. 2015
# 2776 Crime in the U.S. 2015
# 2777 Crime in the U.S. 2015
# 2778 Crime in the U.S. 2015
# 2779 Crime in the U.S. 2015
# 2780 Crime in the U.S. 2015
# 2781 Crime in the U.S. 2015
# 2782 Crime in the U.S. 2015
# 2783 Crime in the U.S. 2015
# 2784 Crime in the U.S. 2015
# 2785 Crime in the U.S. 2015
# 2786 Crime in the U.S. 2015
# 2787 Crime in the U.S. 2015
# 2788 Crime in the U.S. 2015
# 2789 Crime in the U.S. 2015
# 2790 Crime in the U.S. 2015
# 2791 Crime in the U.S. 2015
# 2792 Crime in the U.S. 2015
# 2793 Crime in the U.S. 2015
# 2795 Crime in the U.S. 2015
# 2796 Crime in the U.S. 2015
# 2798 Crime in the U.S. 2015
# 2799 Crime in the U.S. 2015
# 2800 Crime in the U.S. 2015
# 2803 Crime in the U.S. 2015
# 2806 Crime in the U.S. 2015
# 2807 Crime in the U.S. 2015
# 2809 Crime in the U.S. 2015
# 2810 Crime in the U.S. 2015
# 2812
# 2813 Crime in the U.S. 2015
# 2814 Raleigh Police Department
# 2815 Crime in the U.S. 2015
# 2817 Crime in the U.S. 2015
# 2818 Crime in the U.S. 2015
# 2819 Crime in the U.S. 2015
# 2820 Crime in the U.S. 2015
# 2821 Crime in the U.S. 2015
# 2823 Crime in the U.S. 2015
# 2825 Crime in the U.S. 2015
# 2827 Crime in the U.S. 2015
# 2828 Crime in the U.S. 2015
#      url
# 2761 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2763 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2765 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2766 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2767
# 2768 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2770 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2771 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2774 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2775 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2776 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2777 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2778 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2779 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-10/table_10_offenses_known_to_law_enforcement_by_state_by_metropolitan_and_nonmetropolitan_counties_2015.xls
# 2780 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2781 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2782 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2783 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2784 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2785 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2786 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2787 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2788 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2789 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2790 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-10/table_10_offenses_known_to_law_enforcement_by_state_by_metropolitan_and_nonmetropolitan_counties_2015.xls
# 2791 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2792 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2793 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2795 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-10/table_10_offenses_known_to_law_enforcement_by_state_by_metropolitan_and_nonmetropolitan_counties_2015.xls
# 2796 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2798 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-10/table_10_offenses_known_to_law_enforcement_by_state_by_metropolitan_and_nonmetropolitan_counties_2015.xls
# 2799 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2800 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-10/table_10_offenses_known_to_law_enforcement_by_state_by_metropolitan_and_nonmetropolitan_counties_2015.xls
# 2803 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2806 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2807 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2809 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2810 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2812
# 2813 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-10/table_10_offenses_known_to_law_enforcement_by_state_by_metropolitan_and_nonmetropolitan_counties_2015.xls
# 2814
# 2815 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2817 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2818 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2819 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2820 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2821 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2823 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-10/table_10_offenses_known_to_law_enforcement_by_state_by_metropolitan_and_nonmetropolitan_counties_2015.xls
# 2825 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2827 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls
# 2828 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls

# %%
# Randomly pick a row from the group of cities larger than Miami
larger_cities[sample(nrow(larger_cities),1),]
# Out:
#      ORI     year department_name total_pop homs_sum rape_sum rob_sum
# 2807 NB02802 2015 Omaha, Neb.     452252    48       174      655
#      agg_ass_sum violent_crime months_reported violent_per_100k homs_per_100k
# 2807 1452        2329          NA              514.9784         10.61355
#      rape_per_100k rob_per_100k agg_ass_per_100k source
# 2807 38.47413      144.8308     321.0599         Crime in the U.S. 2015
#      url
# 2807 https://ucr.fbi.gov/crime-in-the-u.s/2015/crime-in-the-u.s.-2015/tables/table-8/table_8_offenses_known_to_law_enforcement_by_state_by_city_2015.xls

# %%
# Make a dataframe of a randomly picked city
larger_city <- larger_cities[sample(nrow(larger_cities),1),]$department_name
df_larger_city <- filter(ucr, department_name==larger_city)
head(df_larger_city)
# Out:
#   ORI     year department_name total_pop homs_sum rape_sum rob_sum agg_ass_sum
# 1 TX07102 1975 El Paso, Texas  369000    21       122      840      635
# 2 TX07102 1976 El Paso, Texas  361413    25       118      792      638
# 3 TX07102 1977 El Paso, Texas  386000    32       107      824      597
# 4 TX07102 1978 El Paso, Texas  399000    21       121      775      573
# 5 TX07102 1979 El Paso, Texas  413244    33       175      813     1224
# 6 TX07102 1980 El Paso, Texas  425122    54       218      828     1711
#   violent_crime months_reported violent_per_100k homs_per_100k rape_per_100k
# 1 1618          12              438.4824          5.691057     33.06233
# 2 1573          12              435.2361          6.917294     32.64963
# 3 1560          12              404.1451          8.290155     27.72021
# 4 1490          12              373.4336          5.263158     30.32581
# 5 2245          12              543.2626          7.985597     42.34786
# 6 2811          12              661.2220         12.702236     51.27940
#   rob_per_100k agg_ass_per_100k source url
# 1 227.6423     172.0867         NA     NA
# 2 219.1399     176.5293         NA     NA
# 3 213.4715     154.6632         NA     NA
# 4 194.2356     143.6090         NA     NA
# 5 196.7361     296.1930         NA     NA
# 6 194.7676     402.4727         NA     NA

# %%
# Do the same for smaller cities
smaller_cities <- ucr[(ucr$year==2015) & (ucr$total_pop < miami_pop) & (!is.na(ucr$ORI)),]
smaller_city <- smaller_cities[sample(nrow(smaller_cities),1),]$department_name
df_smaller_city <- filter(ucr, department_name==smaller_city)
head(df_smaller_city)
# Out:
#   ORI     year department_name total_pop homs_sum rape_sum rob_sum agg_ass_sum
# 1 FL04804 1975 Orlando, Fla.   118457    21        86      304      705
# 2 FL04804 1976 Orlando, Fla.   116848    17        98      327      676
# 3 FL04804 1977 Orlando, Fla.   118374    15        85      274      769
# 4 FL04804 1978 Orlando, Fla.   118393    13       107      410     1090
# 5 FL04804 1979 Orlando, Fla.   121515    17       133      496     1080
# 6 FL04804 1980 Orlando, Fla.   127811    17       190      742     1401
#   violent_crime months_reported violent_per_100k homs_per_100k rape_per_100k
# 1 1116          12               942.1140        17.72795       72.60018
# 2 1118          12               956.7986        14.54882       83.86964
# 3 1143          12               965.5837        12.67170       71.80631
# 4 1620          12              1368.3241        10.98038       90.37696
# 5 1726          12              1420.4008        13.99004      109.45151
# 6 2350          12              1838.6524        13.30089      148.65700
#   rob_per_100k agg_ass_per_100k source url
# 1 256.6332      595.1527        NA     NA
# 2 279.8507      578.5294        NA     NA
# 3 231.4697      649.6359        NA     NA
# 4 346.3043      920.6625        NA     NA
# 5 408.1801      888.7792        NA     NA
# 6 580.5447     1096.1498        NA     NA

# %% [markdown]
# - **Plotting the larger city**

# %%
options(repr.plot.width=8,repr.plot.height=4)

plot(df_larger_city$year,df_larger_city$violent_per_100k,xlab="Year",ylab="Violent Crimes per 100K People",type="l",main=paste('Crime rate in',larger_city))
points(df_larger_city$year,df_larger_city$violent_per_100k,pch=19,cex=0.5)
# Out:
# Plot with title “Crime rate in El Paso, Texas”

# %% [markdown]
# - **Plotting the smaller city**

# %%
options(repr.plot.width=8,repr.plot.height=4)

plot(df_smaller_city$year,df_smaller_city$violent_per_100k,xlab="Year",ylab="Violent Crimes per 100K People",type="l",main=paste('Crime rate in',smaller_city))
points(df_smaller_city$year,df_smaller_city$violent_per_100k,pch=19,cex=0.5)
# Out:
# Plot with title “Crime rate in Orlando, Fla.”

# %% [markdown]
# We'll see some better tools for plotting using `ggplot2` next time.
#
# **Short bonus.** See if you can get the data into shape from the Major Cities Chiefs Association for 2016-2017, and update our analysis. The original report that generated the CSV we used [is posted here](https://www.majorcitieschiefs.com/pdf/news/mcca_violent_crime_data_midyear_20162015.pdf). An updated version for 2016-2017 [is posted here](https://www.majorcitieschiefs.com/pdf/news/mcca_violent_crime_report_2017_and_2016_midyear_07312017_update.pdf). Grab the file and see what you can do with it. Remember, I used [Tabula](http://tabula.technology/) to pull the data from the Chiefs' report and convert it to the more usable CSV file we loaded into R. See what you can do to convert the new file and try loading it into R.

# %% [markdown]
# [I tried to get a csv out the pdf reports here](https://github.com/Yuanqi-Hong/r-stat/blob/master/homework/Untitled.ipynb)
